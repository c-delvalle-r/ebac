# %% [markdown]
# # Actividad Módulo 39: Bases de Datos no Relacionales (No SQL)
# - Conexión a la plataforma seleccionada de bases de datos no SQL
# - Generar una nueva base de datos
# - Explorar el archivo de tweets con palabras clave definidos para el caso (incluir 5)
# - Importar por lo menos 1000 tweets a la base de datos a una nueva estructura
# - Construir 2 filtros de búsqueda que se considere importante dentro de la base de datos de tweets proporcionada
# - Obtener screenshots de cada caso de  uso requerido

# %%
from pymongo import MongoClient

client = MongoClient('mongodb+srv://delvalle-carlos:F836zVaPPra78qUp@ebac-test.pg6qpnt.mongodb.net/')

# %%
# Explorar el archivo de tweets con palabras clave definidos para el caso (incluir 5)
import pandas as pd 
df = pd.read_csv('Tweets.csv')
df.sample(5)
# Out:
#                 tweet_id airline_sentiment  airline_sentiment_confidence  \
# 5210  569258359670644736          negative                        1.0000
# 2649  568970614238617600          negative                        1.0000
# 7768  569262534232039427          negative                        1.0000
# 7924  568972783234912257          negative                        0.6854
# 9856  569638479157723136           neutral                        0.6682
#
#                    negativereason  negativereason_confidence     airline  \
# 5210                   Can't Tell                     1.0000   Southwest
# 2649       Customer Service Issue                     0.6492      United
# 7768  Flight Attendant Complaints                     0.3683       Delta
# 7924                  Late Flight                     0.3512       Delta
# 9856                          NaN                     0.0000  US Airways
#
#      airline_sentiment_gold             name negativereason_gold  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tweet_id                      14640 non-null  int64
#  1   airline_sentiment             14640 non-null  object
#  2   airline_sentiment_confidence  14640 non-null  float64
#  3   negativereason                9178 non-null   object
#  4   negativereason_confidence     10522 non-null  float64
#  5   airline                       14640 non-null  object
#  6   airline_sentiment_gold        40 non-null     object
#  7   name                          14640 non-null  object
#  8   negativereason_gold           32 non-null     object
#  9   retweet_count                 14640 non-null  int64
#  10  text                          14640 non-null  object
#  11  tweet_coord                   1019 non-null   object
# ...

# %%
# Change text string to lowercase to facilitate search
df['text'] = df['text'].str.lower()

# %%
df[df['text'].str.contains('thank')].head(2)
# Out:
#               tweet_id airline_sentiment  airline_sentiment_confidence  \
# 14  570285904809598977          positive                        1.0000
# 50  570009035455344640           neutral                        0.6764
#
#    negativereason  negativereason_confidence         airline  \
# 14            NaN                        NaN  Virgin America
# 50            NaN                        0.0  Virgin America
#
#    airline_sentiment_gold         name negativereason_gold  retweet_count  \
# 14                    NaN     sjespers                 NaN              0
# 50                    NaN  grantbrowne                 NaN              0
#
#                                                  text tweet_coord  \
# 14                             @virginamerica thanks!         NaN
# 50  @virginamerica is flight 769 on it's way? was ...         NaN
#
#                 tweet_created     tweet_location               user_timezone
# ...

# %%
df[df['text'].str.contains('angry')].head(2)
# Out:
#                tweet_id airline_sentiment  airline_sentiment_confidence  \
# 947  569995897234288640          negative                         0.688
# 973  569983149028962304          negative                         1.000
#
#              negativereason  negativereason_confidence airline  \
# 947              Can't Tell                     0.6880  United
# 973  Customer Service Issue                     0.3507  United
#
#     airline_sentiment_gold         name negativereason_gold  retweet_count  \
# 947                    NaN  mjc_collins                 NaN              1
# 973                    NaN   ryanaround                 NaN              0
#
#                                                   text tweet_coord  \
# 947  @united just got demoted from gold cuz my hubb...         NaN
# 973  @united premier gold desk changes flight. waiv...         NaN
#
#                  tweet_created tweet_location               user_timezone
# ...

# %%
df[df['text'].str.contains('dissapointed')].head(2)
# Out:
#                 tweet_id airline_sentiment  airline_sentiment_confidence  \
# 7328  569668536966053888          negative                           1.0
# 9708  569703596914282496          negative                           1.0
#
#      negativereason  negativereason_confidence     airline  \
# 7328      longlines                     0.3444       Delta
# 9708    Late Flight                     0.6559  US Airways
#
#      airline_sentiment_gold            name negativereason_gold  \
# 7328                    NaN  SaulFernandezS                 NaN
# 9708                    NaN      lasslawqsb                 NaN
#
#       retweet_count                                               text  \
# 7328              0  @jetblue i'm dissapointed in the way paseenger...
# 9708              0  @usairways truly dissapointed when our flight ...
#
#      tweet_coord              tweet_created tweet_location user_timezone
# 7328         NaN  2015-02-22 17:22:17 -0800            NaN      Santiago
# ...

# %%
df[df['text'].str.contains('sad')].head(2)
# Out:
#                tweet_id airline_sentiment  airline_sentiment_confidence  \
# 145  569609971383586817          negative                           1.0
# 186  569311060903268352          negative                           1.0
#
#        negativereason  negativereason_confidence         airline  \
# 145  Cancelled Flight                      1.000  Virgin America
# 186        Can't Tell                      0.648  Virgin America
#
#     airline_sentiment_gold            name negativereason_gold  retweet_count  \
# 145                    NaN       mlorenzen                 NaN              0
# 186                    NaN  MarwaYousofzoy                 NaN              0
#
#                                                   text tweet_coord  \
# 145  @virginamerica i paid the premium to fly you a...         NaN
# 186  @virginamerica a lot of "apologies" being thro...         NaN
#
#                  tweet_created                tweet_location  \
# ...

# %%
df[df['text'].str.contains('happy')].head(2)
# Out:
#                tweet_id airline_sentiment  airline_sentiment_confidence  \
# 152  569580805036453888          positive                        1.0000
# 308  568802396907835393          positive                        0.6658
#
#     negativereason  negativereason_confidence         airline  \
# 152            NaN                        NaN  Virgin America
# 308            NaN                        NaN  Virgin America
#
#     airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 152                    NaN  paulnakada                 NaN              0
# 308                    NaN  AdamSinger                 NaN              0
#
#                                                   text tweet_coord  \
# 152  @virginamerica thank you for checking in. tick...         NaN
# 308  @virginamerica happy to spend the day together...         NaN
#
#                  tweet_created     tweet_location               user_timezone
# ...

# %%
import pprint
pp = pprint.PrettyPrinter(indent = 4)

filter = {
    'negativereason':'Lost Luggage'
}

result = client['Tweets']['Tweets'].find(
    filter = filter
)

for doc in result:
    pp.pprint(doc)
# Out:
# {   '_id': ObjectId('654adad37cda1e8b62f123e2'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'negative',
#     'airline_sentiment_confidence': 1.0,
#     'name': 'gianagon',
#     'negativereason': 'Lost Luggage',
#     'negativereason_confidence': 1.0,
#     'retweet_count': 0,
#     'text': '@VirginAmerica everything was fine until you lost my bag',
#     'tweet_coord': [40.6413712, -73.78311558],
#     'tweet_created': datetime.datetime(2015, 2, 23, 21, 8, 21),
#     'tweet_id': 569967019958730753,
#     'tweet_location': 'New York + Panama',
#     'user_timezone': 'Eastern Time (US & Canada)'}
# {   '_id': ObjectId('654adad37cda1e8b62f12490'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'negative',
#     'airline_sentiment_confidence': 0.6473,
#     'name': 'RedSoxGirl1976',
#     'negativereason': 'Lost Luggage',
#     'negativereason_confidence': 0.3341,
#     'retweet_count': 0,
# ...

# %%
filter = {
    'airline': 'American'
}

result = client['Tweets']['Tweets'].find(
    filter = filter
)

for doc in result:
    pp.pprint(doc)
# Out:
# {   '_id': ObjectId('654adad67cda1e8b62f15204'),
#     'airline': 'American',
#     'airline_sentiment': 'negative',
#     'airline_sentiment_confidence': 1.0,
#     'name': 'SweeLoTmac',
#     'negativereason': 'Customer Service Issue',
#     'negativereason_confidence': 1.0,
#     'retweet_count': 0,
#     'text': '@AmericanAir why would I even consider continuing your point '
#             'program when I received no perks or continued bad customer '
#             'service? #senseless',
#     'tweet_created': datetime.datetime(2015, 2, 24, 19, 44, 31),
#     'tweet_id': 570308309682675712,
#     'user_timezone': 'Quito'}
# {   '_id': ObjectId('654adad67cda1e8b62f15205'),
#     'airline': 'American',
#     'airline_sentiment': 'neutral',
#     'airline_sentiment_confidence': 0.6667,
#     'name': 'LancasterPattie',
#     'retweet_count': 0,
#     'text': "@AmericanAir we've already made other arrangements ourselves.",
# ...
