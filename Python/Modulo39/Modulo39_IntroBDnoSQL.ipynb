# %% [markdown]
# # Módulo 39: Introducción a Bases de Datos no Relacionales (No SQL)
# - Conceptos básicos de BD no SQL
# - Diferencias con las BD SQL
# - Recomendaciones de cuándo usar SQL y cuándo no SQL
# - Ejemplo con una base de datos pública de Tweets
#     - Script te python para importar los tweets
# - Filtros para búsqueda de información dentro de la BD no SQL
#
# ---
#
# ## BD no SQL
# - Necesidad de escalabilidad y preformance. Nace en 2008-2009 con Web 2.0
# - Se hace el release de varios productos como BigTable, DynamoDB
# - Todos ellos enfocados en mejoras de la búsqueda, así como su performance
# - Al inicio surgieron soluciones propietarias para luego abrirse a open source como MongoDB, Hypertable, Cassandra, etc.
#
# ### Principales diferencias contra una BD SQL
# - Bases de datos NoSQL Data no son estructuradas, sino dinámicas
# - Esto quiere decir uqe no tienen una estructura fija de tablas como en un RDBMS (Relational DataBase Management System)
# - No tienen un esquema de tablas, sino una colección de documentos basados en pares tipo **key-value**. Esto quiere decir que internamente todos los valores de una base de datos NoSQL tienen una llave única
#
# ### Ventajas
# - Mayor flexibilidad. Los tipos de storage de NoSQL son: documentos, key-value, gráficos, objetos, json, xml, entre otros
# - Mayor simpleza. No se tienen esquemas de tablas, sino documentos
# - Escalabilidad. Es más natural y fácil de conseeguir, siendo que añadir nodos y crecer horizontalmente (más procesamiento) es más fácil que escalar un RDBMS, que usualmente requiere mayores servidores
#
# ### Desventajas
# - No soporta ACID (Atomicidad, Consistencia, Independencia y Durabilidad). Aquí está el principal trade-off
# - Si se quiere garantizar consistencia y durabilidad, se debería generar código adicional. Esto limita el número de aplicaciones que utilizan una base NoSQL
# - Se debe aprender un nuevo lenguaje
#
# ### Summary
# - No SQL
#     - High performance
#     - Poor reliabilidy
#     - Good availability
#     - Poor consistency
#     - Optimized Data storage for huge data
#     - High scalability
# - SQL
#     - Low performance
#     - Good reliability
#     - Good availability
#     - Good consistency
#     - Optimized Data Storage for medium to large data
#     - High scalability (but expensive)
#
#
# MongoDB Password
# delvalle-carlos
# F836zVaPPra78qUp

# %%
# Generar conexión con MongoDB Client
from pymongo import MongoClient

# Requires the PyMongo package.
# https://api.mongodb.com/python/current

client = MongoClient('mongodb+srv://delvalle-carlos:F836zVaPPra78qUp@ebac-test.pg6qpnt.mongodb.net/')

# %% [markdown]
# ## Query básico - obtener resultados con base a un registro determinado

# %%
filter = {
    'username': 'andrewhamilton'
}

result = client['sample_analytics']['customers'].find(
    filter
)

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)

for doc in result:
    pp.pprint(doc)
# Out:
# {   '_id': ObjectId('5ca4bbcea2dd94ee58162a6f'),
#     'accounts': [385397, 337979, 325377, 440243, 586395, 86702],
#     'address': '633 Miller Turnpike\nJonathanland, OR 62874',
#     'birthdate': datetime.datetime(1993, 2, 25, 17, 37, 29),
#     'email': 'laura34@yahoo.com',
#     'name': 'Gary Nichols',
#     'tier_and_details': {},
#     'username': 'andrewhamilton'}

# %%
# Buscar una cuenta determinada
filter = {
    'account_id': 716662
}

result = client['sample_analytics']['transactions'].find(
    filter=filter
)

for doc in result:
    pp.pprint(doc)
# Out:
# {   '_id': ObjectId('5ca4bbc1a2dd94ee58161cb2'),
#     'account_id': 716662,
#     'bucket_end_date': datetime.datetime(2016, 12, 27, 0, 0),
#     'bucket_start_date': datetime.datetime(1962, 5, 13, 0, 0),
#     'transaction_count': 48,
#     'transactions': [   {   'amount': 8592,
#                             'date': datetime.datetime(2008, 3, 19, 0, 0),
#                             'price': '6.25868566899633460565155473886989057064056396484375',
#                             'symbol': 'amd',
#                             'total': '53774.62726801650693175815832',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5360,
#                             'date': datetime.datetime(2008, 5, 27, 0, 0),
#                             'price': '6.8846943545406844577883020974695682525634765625',
#                             'symbol': 'amd',
#                             'total': '36901.96174033806869374529924',
#                             'transaction_code': 'sell'},
#                         {   'amount': 4878,
#                             'date': datetime.datetime(2015, 11, 5, 0, 0),
#                             'price': '2.226658409790678749828884974704124033451080322265625',
#                             'symbol': 'amd',
#                             'total': '10861.63972295893094166530091',
#                             'transaction_code': 'buy'},
#                         {   'amount': 653,
#                             'date': datetime.datetime(2015, 10, 21, 0, 0),
#                             'price': '2.373837436769802078373459153226576745510101318359375',
#                             'symbol': 'znga',
#                             'total': '1550.115846210680757177868827',
#                             'transaction_code': 'sell'},
#                         {   'amount': 8043,
#                             'date': datetime.datetime(2014, 12, 9, 0, 0),
#                             'price': '2.4728822736764062284464671392925083637237548828125',
#                             'symbol': 'znga',
#                             'total': '19889.39212717933529539493520',
#                             'transaction_code': 'sell'},
#                         {   'amount': 5675,
#                             'date': datetime.datetime(2006, 4, 27, 0, 0),
#                             'price': '32.416346686685045597187126986682415008544921875',
#                             'symbol': 'amd',
#                             'total': '183962.7674469376337640369456',
#                             'transaction_code': 'buy'},
#                         {   'amount': 7127,
#                             'date': datetime.datetime(1973, 2, 6, 0, 0),
#                             'price': '17.956209262859136543966087629087269306182861328125',
#                             'symbol': 'ibm',
#                             'total': '127973.9034163970661488463065',
#                             'transaction_code': 'sell'},
#                         {   'amount': 9428,
#                             'date': datetime.datetime(2013, 10, 4, 0, 0),
#                             'price': '160.086898842170427315068081952631473541259765625',
#                             'symbol': 'ibm',
#                             'total': '1509299.282283982788726461877',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4762,
#                             'date': datetime.datetime(1994, 8, 2, 0, 0),
#                             'price': '13.3279381594159982427072463906370103359222412109375',
#                             'symbol': 'amd',
#                             'total': '63467.64151513898363177190731',
#                             'transaction_code': 'buy'},
#                         {   'amount': 3750,
#                             'date': datetime.datetime(2013, 2, 12, 0, 0),
#                             'price': '3.3629426011610643598714887048117816448211669921875',
#                             'symbol': 'znga',
#                             'total': '12611.03475435399134951808264',
#                             'transaction_code': 'sell'},
#                         {   'amount': 7508,
#                             'date': datetime.datetime(1990, 3, 29, 0, 0),
#                             'price': '22.209380146876792849752746406011283397674560546875',
#                             'symbol': 'ibm',
#                             'total': '166748.0261427509607159436200',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2157,
#                             'date': datetime.datetime(2015, 2, 20, 0, 0),
#                             'price': '2.310551619513003362982317412388511002063751220703125',
#                             'symbol': 'znga',
#                             'total': '4983.859843289548253952858659',
#                             'transaction_code': 'sell'},
#                         {   'amount': 6178,
#                             'date': datetime.datetime(2009, 5, 20, 0, 0),
#                             'price': '87.2363145379931808065521181561052799224853515625',
#                             'symbol': 'ibm',
#                             'total': '538945.9512157218710228789860',
#                             'transaction_code': 'buy'},
#                         {   'amount': 2348,
#                             'date': datetime.datetime(1987, 9, 8, 0, 0),
#                             'price': '33.09028484414860571405370137654244899749755859375',
#                             'symbol': 'ibm',
#                             'total': '77695.98881406092621659809083',
#                             'transaction_code': 'sell'},
#                         {   'amount': 1636,
#                             'date': datetime.datetime(1968, 5, 22, 0, 0),
#                             'price': '13.7785547229763576382310930057428777217864990234375',
#                             'symbol': 'ibm',
#                             'total': '22541.71552678932109614606816',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4041,
#                             'date': datetime.datetime(2016, 5, 6, 0, 0),
#                             'price': '3.7014628783847296489284417475573718547821044921875',
#                             'symbol': 'amd',
#                             'total': '14957.61149155269251131983310',
#                             'transaction_code': 'buy'},
#                         {   'amount': 8320,
#                             'date': datetime.datetime(2016, 3, 1, 0, 0),
#                             'price': '2.135230517281893281023030795040540397167205810546875',
#                             'symbol': 'amd',
#                             'total': '17765.11790378535209811161621',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5839,
#                             'date': datetime.datetime(1998, 9, 2, 0, 0),
#                             'price': '51.42269939080775742468176758848130702972412109375',
#                             'symbol': 'ibm',
#                             'total': '300257.1417429264956027168409',
#                             'transaction_code': 'sell'},
#                         {   'amount': 7424,
#                             'date': datetime.datetime(2010, 5, 21, 0, 0),
#                             'price': '7.85096989677664236495502336765639483928680419921875',
#                             'symbol': 'amd',
#                             'total': '58285.60051366979291742609348',
#                             'transaction_code': 'buy'},
#                         {   'amount': 1570,
#                             'date': datetime.datetime(1992, 11, 18, 0, 0),
#                             'price': '8.1172357797963687886522166081704199314117431640625',
#                             'symbol': 'amd',
#                             'total': '12744.06017428029899818398007',
#                             'transaction_code': 'sell'},
#                         {   'amount': 4035,
#                             'date': datetime.datetime(2006, 3, 28, 0, 0),
#                             'price': '35.0030390814623473261235631071031093597412109375',
#                             'symbol': 'amd',
#                             'total': '141237.2626937005714609085771',
#                             'transaction_code': 'buy'},
#                         {   'amount': 2396,
#                             'date': datetime.datetime(1983, 8, 3, 0, 0),
#                             'price': '14.59782750387503114097853540442883968353271484375',
#                             'symbol': 'amd',
#                             'total': '34976.39469928457461378457083',
#                             'transaction_code': 'sell'},
#                         {   'amount': 7561,
#                             'date': datetime.datetime(1992, 11, 4, 0, 0),
#                             'price': '14.357152597134703597703264676965773105621337890625',
#                             'symbol': 'ibm',
#                             'total': '108554.4307869354939022343842',
#                             'transaction_code': 'sell'},
#                         {   'amount': 8861,
#                             'date': datetime.datetime(2016, 7, 15, 0, 0),
#                             'price': '2.770691871315896559480052019353024661540985107421875',
#                             'symbol': 'znga',
#                             'total': '24551.10067173015941355274094',
#                             'transaction_code': 'sell'},
#                         {   'amount': 989,
#                             'date': datetime.datetime(2016, 8, 5, 0, 0),
#                             'price': '2.80697525503529021762005868367850780487060546875',
#                             'symbol': 'znga',
#                             'total': '2776.098527229902025226238038',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6991,
#                             'date': datetime.datetime(1991, 12, 27, 0, 0),
#                             'price': '18.54093120162320929011912085115909576416015625',
#                             'symbol': 'ibm',
#                             'total': '129619.6500305478561472227739',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4448,
#                             'date': datetime.datetime(1990, 8, 13, 0, 0),
#                             'price': '2.838456255649362436344063098658807575702667236328125',
#                             'symbol': 'amd',
#                             'total': '12625.45342512836411685839266',
#                             'transaction_code': 'buy'},
#                         {   'amount': 1390,
#                             'date': datetime.datetime(1969, 5, 12, 0, 0),
#                             'price': '13.518939299984577218083359184674918651580810546875',
#                             'symbol': 'ibm',
#                             'total': '18791.32562697856233313586927',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5871,
#                             'date': datetime.datetime(2015, 7, 21, 0, 0),
#                             'price': '1.7818592313361925061343526976997964084148406982421875',
#                             'symbol': 'amd',
#                             'total': '10461.29554717478620351478469',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5780,
#                             'date': datetime.datetime(2013, 3, 13, 0, 0),
#                             'price': '2.57150053033337311347850118181668221950531005859375',
#                             'symbol': 'amd',
#                             'total': '14863.27306532689659590573683',
#                             'transaction_code': 'buy'},
#                         {   'amount': 9500,
#                             'date': datetime.datetime(2015, 9, 15, 0, 0),
#                             'price': '135.51450066929822924066684208810329437255859375',
#                             'symbol': 'ibm',
#                             'total': '1287387.756358333177786335000',
#                             'transaction_code': 'sell'},
#                         {   'amount': 242,
#                             'date': datetime.datetime(2014, 3, 5, 0, 0),
#                             'price': '164.977497536350909967950428836047649383544921875',
#                             'symbol': 'ibm',
#                             'total': '39924.55440379692021224400378',
#                             'transaction_code': 'sell'},
#                         {   'amount': 1810,
#                             'date': datetime.datetime(2006, 10, 12, 0, 0),
#                             'price': '24.215488489677564842850188142620027065277099609375',
#                             'symbol': 'amd',
#                             'total': '43830.03416631639236555884054',
#                             'transaction_code': 'sell'},
#                         {   'amount': 3630,
#                             'date': datetime.datetime(2016, 1, 21, 0, 0),
#                             'price': '2.309741010601587873907192260958254337310791015625',
#                             'symbol': 'znga',
#                             'total': '8384.359868483763982283107907',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6707,
#                             'date': datetime.datetime(2008, 1, 24, 0, 0),
#                             'price': '7.6788139003430675444406006135977804660797119140625',
#                             'symbol': 'amd',
#                             'total': '51501.80482960095402056310832',
#                             'transaction_code': 'sell'},
#                         {   'amount': 9063,
#                             'date': datetime.datetime(2010, 5, 10, 0, 0),
#                             'price': '8.8885831792233371828615418053232133388519287109375',
#                             'symbol': 'amd',
#                             'total': '80557.22935330110488827415338',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4984,
#                             'date': datetime.datetime(2001, 4, 30, 0, 0),
#                             'price': '98.400576663388932274756371043622493743896484375',
#                             'symbol': 'ibm',
#                             'total': '490428.4740903304384573857533',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2859,
#                             'date': datetime.datetime(2004, 11, 3, 0, 0),
#                             'price': '17.91427224913838500697238487191498279571533203125',
#                             'symbol': 'amd',
#                             'total': '51216.90436028664273493404835',
#                             'transaction_code': 'buy'},
#                         {   'amount': 3420,
#                             'date': datetime.datetime(2016, 4, 13, 0, 0),
#                             'price': '140.642065711619352441630326211452484130859375',
#                             'symbol': 'ibm',
#                             'total': '480995.8647337381853503757156',
#                             'transaction_code': 'sell'},
#                         {   'amount': 346,
#                             'date': datetime.datetime(1995, 7, 26, 0, 0),
#                             'price': '22.558316628407485637808349565602838993072509765625',
#                             'symbol': 'ibm',
#                             'total': '7805.177553428990030681688950',
#                             'transaction_code': 'sell'},
#                         {   'amount': 5663,
#                             'date': datetime.datetime(2016, 2, 2, 0, 0),
#                             'price': '2.40749676118021138648828127770684659481048583984375',
#                             'symbol': 'znga',
#                             'total': '13633.65415856353708168313688',
#                             'transaction_code': 'sell'},
#                         {   'amount': 3840,
#                             'date': datetime.datetime(2006, 4, 18, 0, 0),
#                             'price': '69.471924401937911852655815891921520233154296875',
#                             'symbol': 'ibm',
#                             'total': '266772.1897034415815141983330',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5448,
#                             'date': datetime.datetime(2005, 8, 26, 0, 0),
#                             'price': '21.048637651672013504366987035609781742095947265625',
#                             'symbol': 'amd',
#                             'total': '114672.9779263091295717913454',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5852,
#                             'date': datetime.datetime(1987, 9, 24, 0, 0),
#                             'price': '32.2390980086532152881773072294890880584716796875',
#                             'symbol': 'ibm',
#                             'total': '188663.2015466386158664136019',
#                             'transaction_code': 'sell'},
#                         {   'amount': 9019,
#                             'date': datetime.datetime(2014, 12, 26, 0, 0),
#                             'price': '2.74631542297262232210641741403378546237945556640625',
#                             'symbol': 'znga',
#                             'total': '24769.01879979008072307777866',
#                             'transaction_code': 'sell'},
#                         {   'amount': 8260,
#                             'date': datetime.datetime(2003, 12, 31, 0, 0),
#                             'price': '15.072997391334343575408638571389019489288330078125',
#                             'symbol': 'amd',
#                             'total': '124502.9584524216779328753546',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2753,
#                             'date': datetime.datetime(2015, 5, 21, 0, 0),
#                             'price': '2.958834542401841627423664249363355338573455810546875',
#                             'symbol': 'znga',
#                             'total': '8145.671495232270000297347678',
#                             'transaction_code': 'sell'},
#                         {   'amount': 3875,
#                             'date': datetime.datetime(2012, 1, 31, 0, 0),
#                             'price': '6.7735134650038713033382009598426520824432373046875',
#                             'symbol': 'amd',
#                             'total': '26247.36467689000130043552872',
#                             'transaction_code': 'sell'}]}

# %%
# OR - busca dos cuentas
filter = {
    "$or": [{"account_id": 716662}, {"account_id": 557378}]
}

result = client['sample_analytics']['transactions'].find(
    filter=filter
)

for doc in result:
    pp.pprint(doc)
# Out:
# {   '_id': ObjectId('5ca4bbc1a2dd94ee58161cb2'),
#     'account_id': 716662,
#     'bucket_end_date': datetime.datetime(2016, 12, 27, 0, 0),
#     'bucket_start_date': datetime.datetime(1962, 5, 13, 0, 0),
#     'transaction_count': 48,
#     'transactions': [   {   'amount': 8592,
#                             'date': datetime.datetime(2008, 3, 19, 0, 0),
#                             'price': '6.25868566899633460565155473886989057064056396484375',
#                             'symbol': 'amd',
#                             'total': '53774.62726801650693175815832',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5360,
#                             'date': datetime.datetime(2008, 5, 27, 0, 0),
#                             'price': '6.8846943545406844577883020974695682525634765625',
#                             'symbol': 'amd',
#                             'total': '36901.96174033806869374529924',
#                             'transaction_code': 'sell'},
#                         {   'amount': 4878,
#                             'date': datetime.datetime(2015, 11, 5, 0, 0),
#                             'price': '2.226658409790678749828884974704124033451080322265625',
#                             'symbol': 'amd',
#                             'total': '10861.63972295893094166530091',
#                             'transaction_code': 'buy'},
#                         {   'amount': 653,
#                             'date': datetime.datetime(2015, 10, 21, 0, 0),
#                             'price': '2.373837436769802078373459153226576745510101318359375',
#                             'symbol': 'znga',
#                             'total': '1550.115846210680757177868827',
#                             'transaction_code': 'sell'},
#                         {   'amount': 8043,
#                             'date': datetime.datetime(2014, 12, 9, 0, 0),
#                             'price': '2.4728822736764062284464671392925083637237548828125',
#                             'symbol': 'znga',
#                             'total': '19889.39212717933529539493520',
#                             'transaction_code': 'sell'},
#                         {   'amount': 5675,
#                             'date': datetime.datetime(2006, 4, 27, 0, 0),
#                             'price': '32.416346686685045597187126986682415008544921875',
#                             'symbol': 'amd',
#                             'total': '183962.7674469376337640369456',
#                             'transaction_code': 'buy'},
#                         {   'amount': 7127,
#                             'date': datetime.datetime(1973, 2, 6, 0, 0),
#                             'price': '17.956209262859136543966087629087269306182861328125',
#                             'symbol': 'ibm',
#                             'total': '127973.9034163970661488463065',
#                             'transaction_code': 'sell'},
#                         {   'amount': 9428,
#                             'date': datetime.datetime(2013, 10, 4, 0, 0),
#                             'price': '160.086898842170427315068081952631473541259765625',
#                             'symbol': 'ibm',
#                             'total': '1509299.282283982788726461877',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4762,
#                             'date': datetime.datetime(1994, 8, 2, 0, 0),
#                             'price': '13.3279381594159982427072463906370103359222412109375',
#                             'symbol': 'amd',
#                             'total': '63467.64151513898363177190731',
#                             'transaction_code': 'buy'},
#                         {   'amount': 3750,
#                             'date': datetime.datetime(2013, 2, 12, 0, 0),
#                             'price': '3.3629426011610643598714887048117816448211669921875',
#                             'symbol': 'znga',
#                             'total': '12611.03475435399134951808264',
#                             'transaction_code': 'sell'},
#                         {   'amount': 7508,
#                             'date': datetime.datetime(1990, 3, 29, 0, 0),
#                             'price': '22.209380146876792849752746406011283397674560546875',
#                             'symbol': 'ibm',
#                             'total': '166748.0261427509607159436200',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2157,
#                             'date': datetime.datetime(2015, 2, 20, 0, 0),
#                             'price': '2.310551619513003362982317412388511002063751220703125',
#                             'symbol': 'znga',
#                             'total': '4983.859843289548253952858659',
#                             'transaction_code': 'sell'},
#                         {   'amount': 6178,
#                             'date': datetime.datetime(2009, 5, 20, 0, 0),
#                             'price': '87.2363145379931808065521181561052799224853515625',
#                             'symbol': 'ibm',
#                             'total': '538945.9512157218710228789860',
#                             'transaction_code': 'buy'},
#                         {   'amount': 2348,
#                             'date': datetime.datetime(1987, 9, 8, 0, 0),
#                             'price': '33.09028484414860571405370137654244899749755859375',
#                             'symbol': 'ibm',
#                             'total': '77695.98881406092621659809083',
#                             'transaction_code': 'sell'},
#                         {   'amount': 1636,
#                             'date': datetime.datetime(1968, 5, 22, 0, 0),
#                             'price': '13.7785547229763576382310930057428777217864990234375',
#                             'symbol': 'ibm',
#                             'total': '22541.71552678932109614606816',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4041,
#                             'date': datetime.datetime(2016, 5, 6, 0, 0),
#                             'price': '3.7014628783847296489284417475573718547821044921875',
#                             'symbol': 'amd',
#                             'total': '14957.61149155269251131983310',
#                             'transaction_code': 'buy'},
#                         {   'amount': 8320,
#                             'date': datetime.datetime(2016, 3, 1, 0, 0),
#                             'price': '2.135230517281893281023030795040540397167205810546875',
#                             'symbol': 'amd',
#                             'total': '17765.11790378535209811161621',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5839,
#                             'date': datetime.datetime(1998, 9, 2, 0, 0),
#                             'price': '51.42269939080775742468176758848130702972412109375',
#                             'symbol': 'ibm',
#                             'total': '300257.1417429264956027168409',
#                             'transaction_code': 'sell'},
#                         {   'amount': 7424,
#                             'date': datetime.datetime(2010, 5, 21, 0, 0),
#                             'price': '7.85096989677664236495502336765639483928680419921875',
#                             'symbol': 'amd',
#                             'total': '58285.60051366979291742609348',
#                             'transaction_code': 'buy'},
#                         {   'amount': 1570,
#                             'date': datetime.datetime(1992, 11, 18, 0, 0),
#                             'price': '8.1172357797963687886522166081704199314117431640625',
#                             'symbol': 'amd',
#                             'total': '12744.06017428029899818398007',
#                             'transaction_code': 'sell'},
#                         {   'amount': 4035,
#                             'date': datetime.datetime(2006, 3, 28, 0, 0),
#                             'price': '35.0030390814623473261235631071031093597412109375',
#                             'symbol': 'amd',
#                             'total': '141237.2626937005714609085771',
#                             'transaction_code': 'buy'},
#                         {   'amount': 2396,
#                             'date': datetime.datetime(1983, 8, 3, 0, 0),
#                             'price': '14.59782750387503114097853540442883968353271484375',
#                             'symbol': 'amd',
#                             'total': '34976.39469928457461378457083',
#                             'transaction_code': 'sell'},
#                         {   'amount': 7561,
#                             'date': datetime.datetime(1992, 11, 4, 0, 0),
#                             'price': '14.357152597134703597703264676965773105621337890625',
#                             'symbol': 'ibm',
#                             'total': '108554.4307869354939022343842',
#                             'transaction_code': 'sell'},
#                         {   'amount': 8861,
#                             'date': datetime.datetime(2016, 7, 15, 0, 0),
#                             'price': '2.770691871315896559480052019353024661540985107421875',
#                             'symbol': 'znga',
#                             'total': '24551.10067173015941355274094',
#                             'transaction_code': 'sell'},
#                         {   'amount': 989,
#                             'date': datetime.datetime(2016, 8, 5, 0, 0),
#                             'price': '2.80697525503529021762005868367850780487060546875',
#                             'symbol': 'znga',
#                             'total': '2776.098527229902025226238038',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6991,
#                             'date': datetime.datetime(1991, 12, 27, 0, 0),
#                             'price': '18.54093120162320929011912085115909576416015625',
#                             'symbol': 'ibm',
#                             'total': '129619.6500305478561472227739',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4448,
#                             'date': datetime.datetime(1990, 8, 13, 0, 0),
#                             'price': '2.838456255649362436344063098658807575702667236328125',
#                             'symbol': 'amd',
#                             'total': '12625.45342512836411685839266',
#                             'transaction_code': 'buy'},
#                         {   'amount': 1390,
#                             'date': datetime.datetime(1969, 5, 12, 0, 0),
#                             'price': '13.518939299984577218083359184674918651580810546875',
#                             'symbol': 'ibm',
#                             'total': '18791.32562697856233313586927',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5871,
#                             'date': datetime.datetime(2015, 7, 21, 0, 0),
#                             'price': '1.7818592313361925061343526976997964084148406982421875',
#                             'symbol': 'amd',
#                             'total': '10461.29554717478620351478469',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5780,
#                             'date': datetime.datetime(2013, 3, 13, 0, 0),
#                             'price': '2.57150053033337311347850118181668221950531005859375',
#                             'symbol': 'amd',
#                             'total': '14863.27306532689659590573683',
#                             'transaction_code': 'buy'},
#                         {   'amount': 9500,
#                             'date': datetime.datetime(2015, 9, 15, 0, 0),
#                             'price': '135.51450066929822924066684208810329437255859375',
#                             'symbol': 'ibm',
#                             'total': '1287387.756358333177786335000',
#                             'transaction_code': 'sell'},
#                         {   'amount': 242,
#                             'date': datetime.datetime(2014, 3, 5, 0, 0),
#                             'price': '164.977497536350909967950428836047649383544921875',
#                             'symbol': 'ibm',
#                             'total': '39924.55440379692021224400378',
#                             'transaction_code': 'sell'},
#                         {   'amount': 1810,
#                             'date': datetime.datetime(2006, 10, 12, 0, 0),
#                             'price': '24.215488489677564842850188142620027065277099609375',
#                             'symbol': 'amd',
#                             'total': '43830.03416631639236555884054',
#                             'transaction_code': 'sell'},
#                         {   'amount': 3630,
#                             'date': datetime.datetime(2016, 1, 21, 0, 0),
#                             'price': '2.309741010601587873907192260958254337310791015625',
#                             'symbol': 'znga',
#                             'total': '8384.359868483763982283107907',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6707,
#                             'date': datetime.datetime(2008, 1, 24, 0, 0),
#                             'price': '7.6788139003430675444406006135977804660797119140625',
#                             'symbol': 'amd',
#                             'total': '51501.80482960095402056310832',
#                             'transaction_code': 'sell'},
#                         {   'amount': 9063,
#                             'date': datetime.datetime(2010, 5, 10, 0, 0),
#                             'price': '8.8885831792233371828615418053232133388519287109375',
#                             'symbol': 'amd',
#                             'total': '80557.22935330110488827415338',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4984,
#                             'date': datetime.datetime(2001, 4, 30, 0, 0),
#                             'price': '98.400576663388932274756371043622493743896484375',
#                             'symbol': 'ibm',
#                             'total': '490428.4740903304384573857533',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2859,
#                             'date': datetime.datetime(2004, 11, 3, 0, 0),
#                             'price': '17.91427224913838500697238487191498279571533203125',
#                             'symbol': 'amd',
#                             'total': '51216.90436028664273493404835',
#                             'transaction_code': 'buy'},
#                         {   'amount': 3420,
#                             'date': datetime.datetime(2016, 4, 13, 0, 0),
#                             'price': '140.642065711619352441630326211452484130859375',
#                             'symbol': 'ibm',
#                             'total': '480995.8647337381853503757156',
#                             'transaction_code': 'sell'},
#                         {   'amount': 346,
#                             'date': datetime.datetime(1995, 7, 26, 0, 0),
#                             'price': '22.558316628407485637808349565602838993072509765625',
#                             'symbol': 'ibm',
#                             'total': '7805.177553428990030681688950',
#                             'transaction_code': 'sell'},
#                         {   'amount': 5663,
#                             'date': datetime.datetime(2016, 2, 2, 0, 0),
#                             'price': '2.40749676118021138648828127770684659481048583984375',
#                             'symbol': 'znga',
#                             'total': '13633.65415856353708168313688',
#                             'transaction_code': 'sell'},
#                         {   'amount': 3840,
#                             'date': datetime.datetime(2006, 4, 18, 0, 0),
#                             'price': '69.471924401937911852655815891921520233154296875',
#                             'symbol': 'ibm',
#                             'total': '266772.1897034415815141983330',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5448,
#                             'date': datetime.datetime(2005, 8, 26, 0, 0),
#                             'price': '21.048637651672013504366987035609781742095947265625',
#                             'symbol': 'amd',
#                             'total': '114672.9779263091295717913454',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5852,
#                             'date': datetime.datetime(1987, 9, 24, 0, 0),
#                             'price': '32.2390980086532152881773072294890880584716796875',
#                             'symbol': 'ibm',
#                             'total': '188663.2015466386158664136019',
#                             'transaction_code': 'sell'},
#                         {   'amount': 9019,
#                             'date': datetime.datetime(2014, 12, 26, 0, 0),
#                             'price': '2.74631542297262232210641741403378546237945556640625',
#                             'symbol': 'znga',
#                             'total': '24769.01879979008072307777866',
#                             'transaction_code': 'sell'},
#                         {   'amount': 8260,
#                             'date': datetime.datetime(2003, 12, 31, 0, 0),
#                             'price': '15.072997391334343575408638571389019489288330078125',
#                             'symbol': 'amd',
#                             'total': '124502.9584524216779328753546',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2753,
#                             'date': datetime.datetime(2015, 5, 21, 0, 0),
#                             'price': '2.958834542401841627423664249363355338573455810546875',
#                             'symbol': 'znga',
#                             'total': '8145.671495232270000297347678',
#                             'transaction_code': 'sell'},
#                         {   'amount': 3875,
#                             'date': datetime.datetime(2012, 1, 31, 0, 0),
#                             'price': '6.7735134650038713033382009598426520824432373046875',
#                             'symbol': 'amd',
#                             'total': '26247.36467689000130043552872',
#                             'transaction_code': 'sell'}]}
# {   '_id': ObjectId('5ca4bbc1a2dd94ee58161cb3'),
#     'account_id': 557378,
#     'bucket_end_date': datetime.datetime(2016, 11, 6, 0, 0),
#     'bucket_start_date': datetime.datetime(1990, 6, 11, 0, 0),
#     'transaction_count': 56,
#     'transactions': [   {   'amount': 2561,
#                             'date': datetime.datetime(2006, 10, 6, 0, 0),
#                             'price': '38.236619210617988073863671161234378814697265625',
#                             'symbol': 'adbe',
#                             'total': '97923.98179839266745716486184',
#                             'transaction_code': 'sell'},
#                         {   'amount': 9153,
#                             'date': datetime.datetime(2000, 6, 19, 0, 0),
#                             'price': '31.12236744839008650842515635304152965545654296875',
#                             'symbol': 'adbe',
#                             'total': '284863.0292551144618116154561',
#                             'transaction_code': 'sell'},
#                         {   'amount': 18,
#                             'date': datetime.datetime(2013, 11, 6, 0, 0),
#                             'price': '356.639066345529272439307533204555511474609375',
#                             'symbol': 'amzn',
#                             'total': '6419.503194219526903907535598',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6818,
#                             'date': datetime.datetime(2006, 5, 5, 0, 0),
#                             'price': '13.68280177976553346752552897669374942779541015625',
#                             'symbol': 'ebay',
#                             'total': '93289.34253444140718158905656',
#                             'transaction_code': 'sell'},
#                         {   'amount': 4981,
#                             'date': datetime.datetime(1997, 3, 6, 0, 0),
#                             'price': '5.03453930083013556640025853994302451610565185546875',
#                             'symbol': 'csco',
#                             'total': '25077.04025743490525623968779',
#                             'transaction_code': 'buy'},
#                         {   'amount': 76,
#                             'date': datetime.datetime(1999, 10, 20, 0, 0),
#                             'price': '28.5667682670397340416457154788076877593994140625',
#                             'symbol': 'csco',
#                             'total': '2171.074388295019787165074376',
#                             'transaction_code': 'buy'},
#                         {   'amount': 7530,
#                             'date': datetime.datetime(2011, 8, 23, 0, 0),
#                             'price': '12.1229215166617709797947100014425814151763916015625',
#                             'symbol': 'nvda',
#                             'total': '91285.59902046313547785416631',
#                             'transaction_code': 'buy'},
#                         {   'amount': 7491,
#                             'date': datetime.datetime(2006, 5, 5, 0, 0),
#                             'price': '34.391086176684922293134150095283985137939453125',
#                             'symbol': 'amzn',
#                             'total': '257623.6265495467528978679184',
#                             'transaction_code': 'buy'},
#                         {   'amount': 8811,
#                             'date': datetime.datetime(2011, 5, 3, 0, 0),
#                             'price': '14.271412405798006517443354823626577854156494140625',
#                             'symbol': 'ebay',
#                             'total': '125745.4147074862354251933994',
#                             'transaction_code': 'sell'},
#                         {   'amount': 7657,
#                             'date': datetime.datetime(2012, 12, 21, 0, 0),
#                             'price': '26.371201383486148728252373985014855861663818359375',
#                             'symbol': 'fb',
#                             'total': '201924.2889933534408122284276',
#                             'transaction_code': 'buy'},
#                         {   'amount': 2409,
#                             'date': datetime.datetime(2005, 7, 19, 0, 0),
#                             'price': '14.77759393544652510854575666598975658416748046875',
#                             'symbol': 'ebay',
#                             'total': '35599.22379049067898648672781',
#                             'transaction_code': 'buy'},
#                         {   'amount': 437,
#                             'date': datetime.datetime(2012, 7, 6, 0, 0),
#                             'price': '14.2186606964582740175728758913464844226837158203125',
#                             'symbol': 'csco',
#                             'total': '6213.554724352265745679346765',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4713,
#                             'date': datetime.datetime(2013, 2, 12, 0, 0),
#                             'price': '23.840946773140561987247565411962568759918212890625',
#                             'symbol': 'ebay',
#                             'total': '112362.3821418114686458977758',
#                             'transaction_code': 'sell'},
#                         {   'amount': 4560,
#                             'date': datetime.datetime(2007, 8, 16, 0, 0),
#                             'price': '24.073883498473406916673411615192890167236328125',
#                             'symbol': 'csco',
#                             'total': '109776.9087530387355400307570',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6138,
#                             'date': datetime.datetime(2015, 4, 9, 0, 0),
#                             'price': '81.8382830663750695521230227313935756683349609375',
#                             'symbol': 'fb',
#                             'total': '502323.3814614101769109311135',
#                             'transaction_code': 'buy'},
#                         {   'amount': 25,
#                             'date': datetime.datetime(2012, 3, 19, 0, 0),
#                             'price': '34.0988154814487671728784334845840930938720703125',
#                             'symbol': 'adbe',
#                             'total': '852.4703870362191793219608371',
#                             'transaction_code': 'sell'},
#                         {   'amount': 3265,
#                             'date': datetime.datetime(2006, 7, 20, 0, 0),
#                             'price': '28.066205274294620863884119899012148380279541015625',
#                             'symbol': 'adbe',
#                             'total': '91636.16022057193712058165147',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4088,
#                             'date': datetime.datetime(2002, 10, 24, 0, 0),
#                             'price': '19.98506724035980397502498817630112171173095703125',
#                             'symbol': 'amzn',
#                             'total': '81698.95487859087864990215166',
#                             'transaction_code': 'sell'},
#                         {   'amount': 3037,
#                             'date': datetime.datetime(2005, 6, 30, 0, 0),
#                             'price': '15.8977594477525681071483631967566907405853271484375',
#                             'symbol': 'csco',
#                             'total': '48281.49544282454934140957903',
#                             'transaction_code': 'sell'},
#                         {   'amount': 154,
#                             'date': datetime.datetime(2010, 8, 20, 0, 0),
#                             'price': '9.121796373543844538289704360067844390869140625',
#                             'symbol': 'nvda',
#                             'total': '1404.756641525752058896614471',
#                             'transaction_code': 'buy'},
#                         {   'amount': 7469,
#                             'date': datetime.datetime(2016, 9, 2, 0, 0),
#                             'price': '773.930708106383235644898377358913421630859375',
#                             'symbol': 'amzn',
#                             'total': '5780488.458846576387031745980',
#                             'transaction_code': 'sell'},
#                         {   'amount': 9837,
#                             'date': datetime.datetime(2014, 1, 27, 0, 0),
#                             'price': '54.53935012022706274592565023340284824371337890625',
#                             'symbol': 'fb',
#                             'total': '536503.5871326736162316706213',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2327,
#                             'date': datetime.datetime(2010, 5, 14, 0, 0),
#                             'price': '130.59787649829439715176704339683055877685546875',
#                             'symbol': 'amzn',
#                             'total': '303901.2586115310621721619100',
#                             'transaction_code': 'buy'},
#                         {   'amount': 1531,
#                             'date': datetime.datetime(2012, 1, 12, 0, 0),
#                             'price': '29.27990866992555396564057446084916591644287109375',
#                             'symbol': 'adbe',
#                             'total': '44827.54017365602312139571950',
#                             'transaction_code': 'sell'},
#                         {   'amount': 8555,
#                             'date': datetime.datetime(1994, 10, 18, 0, 0),
#                             'price': '1.2325985509674126650025982598890550434589385986328125',
#                             'symbol': 'csco',
#                             'total': '10544.88060352621534909722811',
#                             'transaction_code': 'buy'},
#                         {   'amount': 9719,
#                             'date': datetime.datetime(1999, 9, 29, 0, 0),
#                             'price': '67.6229613537316964766432647593319416046142578125',
#                             'symbol': 'amzn',
#                             'total': '657227.5613969183580564958902',
#                             'transaction_code': 'sell'},
#                         {   'amount': 6549,
#                             'date': datetime.datetime(2016, 8, 2, 0, 0),
#                             'price': '56.55898438572850039918193942867219448089599609375',
#                             'symbol': 'nvda',
#                             'total': '370404.7887421359491142425213',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6424,
#                             'date': datetime.datetime(2013, 2, 22, 0, 0),
#                             'price': '38.44061560343626382518777973018586635589599609375',
#                             'symbol': 'adbe',
#                             'total': '246942.5146364745588130062970',
#                             'transaction_code': 'buy'},
#                         {   'amount': 8585,
#                             'date': datetime.datetime(2011, 4, 7, 0, 0),
#                             'price': '34.39311043410062751490841037593781948089599609375',
#                             'symbol': 'adbe',
#                             'total': '295264.8530767538872154887031',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6642,
#                             'date': datetime.datetime(2011, 4, 21, 0, 0),
#                             'price': '13.9780811367909567621836686157621443271636962890625',
#                             'symbol': 'csco',
#                             'total': '92842.41491056553481442392695',
#                             'transaction_code': 'buy'},
#                         {   'amount': 3394,
#                             'date': datetime.datetime(1991, 3, 20, 0, 0),
#                             'price': '2.977895009846466489733529670047573745250701904296875',
#                             'symbol': 'adbe',
#                             'total': '10106.97566341890726615559970',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5286,
#                             'date': datetime.datetime(2001, 2, 9, 0, 0),
#                             'price': '6.84957187854324356379720484255813062191009521484375',
#                             'symbol': 'nvda',
#                             'total': '36206.83694997958547823202480',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2453,
#                             'date': datetime.datetime(2000, 12, 1, 0, 0),
#                             'price': '25.59344258565663920990118640474975109100341796875',
#                             'symbol': 'amzn',
#                             'total': '62780.71466261573598188761025',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6589,
#                             'date': datetime.datetime(2011, 9, 22, 0, 0),
#                             'price': '12.6716193016100380219768339884467422962188720703125',
#                             'symbol': 'nvda',
#                             'total': '83493.29957830854052680535915',
#                             'transaction_code': 'sell'},
#                         {   'amount': 8784,
#                             'date': datetime.datetime(2015, 2, 23, 0, 0),
#                             'price': '26.98971687241482442232154426164925098419189453125',
#                             'symbol': 'csco',
#                             'total': '237077.6730072918177256724448',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2633,
#                             'date': datetime.datetime(2014, 11, 19, 0, 0),
#                             'price': '74.119615816870265234683756716549396514892578125',
#                             'symbol': 'fb',
#                             'total': '195156.9484458194083629223314',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2234,
#                             'date': datetime.datetime(2013, 7, 25, 0, 0),
#                             'price': '47.82079446496187102866315399296581745147705078125',
#                             'symbol': 'adbe',
#                             'total': '106831.6548347248198780334860',
#                             'transaction_code': 'sell'},
#                         {   'amount': 6608,
#                             'date': datetime.datetime(2004, 10, 15, 0, 0),
#                             'price': '19.72737711176173291960367350839078426361083984375',
#                             'symbol': 'ebay',
#                             'total': '130358.5079545215311327410745',
#                             'transaction_code': 'sell'},
#                         {   'amount': 1180,
#                             'date': datetime.datetime(2013, 4, 23, 0, 0),
#                             'price': '268.0863719175703181463177315890789031982421875',
#                             'symbol': 'amzn',
#                             'total': '316341.9188627329754126549233',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4164,
#                             'date': datetime.datetime(2005, 9, 16, 0, 0),
#                             'price': '15.8364604348823352353292648331262171268463134765625',
#                             'symbol': 'ebay',
#                             'total': '65943.02125085004391991105877',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6581,
#                             'date': datetime.datetime(2015, 3, 5, 0, 0),
#                             'price': '385.4478570683407951946719549596309661865234375',
#                             'symbol': 'amzn',
#                             'total': '2536632.347366750773176136136',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2301,
#                             'date': datetime.datetime(2014, 4, 28, 0, 0),
#                             'price': '56.3834753833376254306131158955395221710205078125',
#                             'symbol': 'fb',
#                             'total': '129738.3768570598761158407797',
#                             'transaction_code': 'buy'},
#                         {   'amount': 2518,
#                             'date': datetime.datetime(2011, 12, 7, 0, 0),
#                             'price': '15.6681851523501958212136742076836526393890380859375',
#                             'symbol': 'csco',
#                             'total': '39452.49021361779307781603165',
#                             'transaction_code': 'sell'},
#                         {   'amount': 8665,
#                             'date': datetime.datetime(2016, 9, 1, 0, 0),
#                             'price': '126.044496018020055316810612566769123077392578125',
#                             'symbol': 'fb',
#                             'total': '1092175.557996143779320163958',
#                             'transaction_code': 'sell'},
#                         {   'amount': 6087,
#                             'date': datetime.datetime(2015, 8, 25, 0, 0),
#                             'price': '25.557797653399230597415225929580628871917724609375',
#                             'symbol': 'ebay',
#                             'total': '155570.3143162411166464664802',
#                             'transaction_code': 'buy'},
#                         {   'amount': 3170,
#                             'date': datetime.datetime(2008, 2, 8, 0, 0),
#                             'price': '32.32140283470317854153108783066272735595703125',
#                             'symbol': 'adbe',
#                             'total': '102458.8469860090759766535484',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4588,
#                             'date': datetime.datetime(2009, 7, 13, 0, 0),
#                             'price': '28.1323654360777339888954884372651576995849609375',
#                             'symbol': 'adbe',
#                             'total': '129071.2926207246435410525010',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2091,
#                             'date': datetime.datetime(2015, 8, 4, 0, 0),
#                             'price': '93.489905488099083186170901171863079071044921875',
#                             'symbol': 'fb',
#                             'total': '195487.3923756151829422833544',
#                             'transaction_code': 'sell'},
#                         {   'amount': 8488,
#                             'date': datetime.datetime(2001, 4, 3, 0, 0),
#                             'price': '8.9866110545304902501584365381859242916107177734375',
#                             'symbol': 'amzn',
#                             'total': '76278.35463085480124334480934',
#                             'transaction_code': 'sell'},
#                         {   'amount': 191,
#                             'date': datetime.datetime(2015, 11, 19, 0, 0),
#                             'price': '30.732429358015462383946214686147868633270263671875',
#                             'symbol': 'nvda',
#                             'total': '5869.894007380953315333727005',
#                             'transaction_code': 'sell'},
#                         {   'amount': 3702,
#                             'date': datetime.datetime(1992, 6, 8, 0, 0),
#                             'price': '0.53315438718701291254120633311686106026172637939453125',
#                             'symbol': 'csco',
#                             'total': '1973.737541366321802227545845',
#                             'transaction_code': 'sell'},
#                         {   'amount': 1295,
#                             'date': datetime.datetime(2013, 12, 31, 0, 0),
#                             'price': '53.9351119124750226774267503060400485992431640625',
#                             'symbol': 'fb',
#                             'total': '69845.96992665515436726764165',
#                             'transaction_code': 'buy'},
#                         {   'amount': 3138,
#                             'date': datetime.datetime(2002, 12, 27, 0, 0),
#                             'price': '3.7398230127107439102474018000066280364990234375',
#                             'symbol': 'nvda',
#                             'total': '11735.56461388631439035634685',
#                             'transaction_code': 'buy'},
#                         {   'amount': 3725,
#                             'date': datetime.datetime(2007, 8, 28, 0, 0),
#                             'price': '13.9906932477105296896979780285619199275970458984375',
#                             'symbol': 'ebay',
#                             'total': '52115.33234772172309412496816',
#                             'transaction_code': 'buy'},
#                         {   'amount': 2304,
#                             'date': datetime.datetime(2016, 4, 19, 0, 0),
#                             'price': '24.1067020326315883949064300395548343658447265625',
#                             'symbol': 'ebay',
#                             'total': '55541.84148318317966186441481',
#                             'transaction_code': 'buy'},
#                         {   'amount': 1501,
#                             'date': datetime.datetime(2003, 3, 10, 0, 0),
#                             'price': '13.335652746054819317578221671283245086669921875',
#                             'symbol': 'adbe',
#                             'total': '20016.81477182828379568491073',
#                             'transaction_code': 'sell'}]}

# %%
# Fechas 
# Usar la libreria datetime
from datetime import datetime

start = datetime(2003,1,1,1,1,1)
end = datetime(2004,1,1,1,1,1)

filter = {
    "bucket_start_date": {"$gte":start, "$lt": end}
}

result = client['sample_analytics']['transactions'].find(
    filter=filter
)

for doc in result:
    pp.pprint(doc)
# Out:
# {   '_id': ObjectId('5ca4bbc1a2dd94ee58161d59'),
#     'account_id': 165279,
#     'bucket_end_date': datetime.datetime(2016, 12, 11, 0, 0),
#     'bucket_start_date': datetime.datetime(2003, 4, 8, 0, 0),
#     'transaction_count': 5,
#     'transactions': [   {   'amount': 3756,
#                             'date': datetime.datetime(2016, 7, 22, 0, 0),
#                             'price': '746.69134704911766675650142133235931396484375',
#                             'symbol': 'amzn',
#                             'total': '2804572.699516485956337419339',
#                             'transaction_code': 'buy'},
#                         {   'amount': 1706,
#                             'date': datetime.datetime(2014, 7, 17, 0, 0),
#                             'price': '571.31523495895135056343860924243927001953125',
#                             'symbol': 'goog',
#                             'total': '974663.7908399710040612262674',
#                             'transaction_code': 'buy'},
#                         {   'amount': 8614,
#                             'date': datetime.datetime(2003, 12, 1, 0, 0),
#                             'price': '53.92247669794670628107269294559955596923828125',
#                             'symbol': 'amzn',
#                             'total': '464488.2142761129279051601770',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6465,
#                             'date': datetime.datetime(2006, 12, 21, 0, 0),
#                             'price': '41.4198381615216248974320478737354278564453125',
#                             'symbol': 'adbe',
#                             'total': '267779.2537142373049618981895',
#                             'transaction_code': 'buy'},
#                         {   'amount': 3548,
#                             'date': datetime.datetime(2015, 5, 29, 0, 0),
#                             'price': '538.170060219578999749501235783100128173828125',
#                             'symbol': 'goog',
#                             'total': '1909427.373659066291111230385',
#                             'transaction_code': 'buy'}]}
# {   '_id': ObjectId('5ca4bbc1a2dd94ee58161e1e'),
#     'account_id': 590768,
#     'bucket_end_date': datetime.datetime(2015, 10, 18, 0, 0),
#     'bucket_start_date': datetime.datetime(2003, 9, 23, 0, 0),
#     'transaction_count': 9,
#     'transactions': [   {   'amount': 907,
#                             'date': datetime.datetime(2008, 5, 16, 0, 0),
#                             'price': '22.028638158492011456246473244391381740570068359375',
#                             'symbol': 'nvda',
#                             'total': '19979.97480975225439081555123',
#                             'transaction_code': 'buy'},
#                         {   'amount': 3032,
#                             'date': datetime.datetime(2014, 6, 13, 0, 0),
#                             'price': '86.429503360128506983528495766222476959228515625',
#                             'symbol': 'aapl',
#                             'total': '262054.2541879096331740583992',
#                             'transaction_code': 'sell'},
#                         {   'amount': 108,
#                             'date': datetime.datetime(2004, 6, 4, 0, 0),
#                             'price': '19.038288527008585759858760866336524486541748046875',
#                             'symbol': 'csco',
#                             'total': '2056.135160916927262064746174',
#                             'transaction_code': 'sell'},
#                         {   'amount': 7651,
#                             'date': datetime.datetime(2013, 11, 11, 0, 0),
#                             'price': '14.8584599428253767428032006137073040008544921875',
#                             'symbol': 'nvda',
#                             'total': '113682.0770225569574591872879',
#                             'transaction_code': 'buy'},
#                         {   'amount': 906,
#                             'date': datetime.datetime(2007, 4, 24, 0, 0),
#                             'price': '14.1329243118521166167056435369886457920074462890625',
#                             'symbol': 'ebay',
#                             'total': '12804.42942653801765473531304',
#                             'transaction_code': 'buy'},
#                         {   'amount': 9563,
#                             'date': datetime.datetime(2013, 3, 8, 0, 0),
#                             'price': '56.49166651606258682249972480349242687225341796875',
#                             'symbol': 'aapl',
#                             'total': '540229.8068931065177835648683',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4063,
#                             'date': datetime.datetime(2012, 8, 14, 0, 0),
#                             'price': '19.244101369613648699896657490171492099761962890625',
#                             'symbol': 'ebay',
#                             'total': '78188.78386474025466768011938',
#                             'transaction_code': 'sell'},
#                         {   'amount': 933,
#                             'date': datetime.datetime(2012, 6, 18, 0, 0),
#                             'price': '74.111311525242314246497699059545993804931640625',
#                             'symbol': 'aapl',
#                             'total': '69145.85365305107919198235322',
#                             'transaction_code': 'buy'},
#                         {   'amount': 9531,
#                             'date': datetime.datetime(2009, 9, 21, 0, 0),
#                             'price': '10.0516790133623690195463495911099016666412353515625',
#                             'symbol': 'ebay',
#                             'total': '95802.55267635673912529625795',
#                             'transaction_code': 'sell'}]}
# {   '_id': ObjectId('5ca4bbc1a2dd94ee58162076'),
#     'account_id': 541950,
#     'bucket_end_date': datetime.datetime(2016, 10, 20, 0, 0),
#     'bucket_start_date': datetime.datetime(2003, 3, 31, 0, 0),
#     'transaction_count': 4,
#     'transactions': [   {   'amount': 4847,
#                             'date': datetime.datetime(2016, 10, 12, 0, 0),
#                             'price': '128.500581176744475442319526337087154388427734375',
#                             'symbol': 'fb',
#                             'total': '622842.3169636804724689227442',
#                             'transaction_code': 'sell'},
#                         {   'amount': 4684,
#                             'date': datetime.datetime(2004, 3, 8, 0, 0),
#                             'price': '16.64701148378190964649547822773456573486328125',
#                             'symbol': 'bb',
#                             'total': '77974.60179003446478418482002',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5437,
#                             'date': datetime.datetime(2012, 10, 31, 0, 0),
#                             'price': '2.1775061203015173560970652033574879169464111328125',
#                             'symbol': 'znga',
#                             'total': '11839.10077607934986509974351',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6391,
#                             'date': datetime.datetime(2015, 11, 24, 0, 0),
#                             'price': '2.579172437683934671071028787991963326930999755859375',
#                             'symbol': 'znga',
#                             'total': '16483.49104923802648281494498',
#                             'transaction_code': 'sell'}]}
# {   '_id': ObjectId('5ca4bbc1a2dd94ee58162117'),
#     'account_id': 678293,
#     'bucket_end_date': datetime.datetime(2016, 10, 15, 0, 0),
#     'bucket_start_date': datetime.datetime(2003, 4, 13, 0, 0),
#     'transaction_count': 28,
#     'transactions': [   {   'amount': 8634,
#                             'date': datetime.datetime(2011, 11, 1, 0, 0),
#                             'price': '214.382805196037452333257533609867095947265625',
#                             'symbol': 'amzn',
#                             'total': '1850981.140062587363445345545',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6855,
#                             'date': datetime.datetime(2012, 5, 10, 0, 0),
#                             'price': '7.91596797088676140674579073674976825714111328125',
#                             'symbol': 'znga',
#                             'total': '54263.96044042874944324239550',
#                             'transaction_code': 'sell'},
#                         {   'amount': 43,
#                             'date': datetime.datetime(2014, 1, 2, 0, 0),
#                             'price': '54.72446189172026009828186943195760250091552734375',
#                             'symbol': 'fb',
#                             'total': '2353.151861343971184226120386',
#                             'transaction_code': 'sell'},
#                         {   'amount': 3972,
#                             'date': datetime.datetime(2013, 3, 19, 0, 0),
#                             'price': '15.265207128690118310032630688510835170745849609375',
#                             'symbol': 'bb',
#                             'total': '60633.40271515714992744960909',
#                             'transaction_code': 'sell'},
#                         {   'amount': 9447,
#                             'date': datetime.datetime(2015, 10, 23, 0, 0),
#                             'price': '615.177213500241123256273567676544189453125',
#                             'symbol': 'amzn',
#                             'total': '5811579.135936777891402016394',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2262,
#                             'date': datetime.datetime(2015, 11, 30, 0, 0),
#                             'price': '7.8601502265551115300468154600821435451507568359375',
#                             'symbol': 'bb',
#                             'total': '17779.65981246766228096589657',
#                             'transaction_code': 'sell'},
#                         {   'amount': 3803,
#                             'date': datetime.datetime(2013, 4, 19, 0, 0),
#                             'price': '39.88539486971151148964054300449788570404052734375',
#                             'symbol': 'crm',
#                             'total': '151684.1566895128781951029850',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2951,
#                             'date': datetime.datetime(2013, 1, 9, 0, 0),
#                             'price': '11.5446527155233322758931535645388066768646240234375',
#                             'symbol': 'nvda',
#                             'total': '34068.27016350935354616069617',
#                             'transaction_code': 'buy'},
#                         {   'amount': 8190,
#                             'date': datetime.datetime(2006, 4, 3, 0, 0),
#                             'price': '36.0650875903803438404793269000947475433349609375',
#                             'symbol': 'adbe',
#                             'total': '295373.0673652150160535256873',
#                             'transaction_code': 'sell'},
#                         {   'amount': 9261,
#                             'date': datetime.datetime(2014, 3, 3, 0, 0),
#                             'price': '60.630683538978331625912687741219997406005859375',
#                             'symbol': 'crm',
#                             'total': '561500.7602544783291875774012',
#                             'transaction_code': 'sell'},
#                         {   'amount': 8225,
#                             'date': datetime.datetime(2016, 4, 28, 0, 0),
#                             'price': '76.3142732132773318198815104551613330841064453125',
#                             'symbol': 'crm',
#                             'total': '627684.8971792060542185254235',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5324,
#                             'date': datetime.datetime(2015, 7, 9, 0, 0),
#                             'price': '86.699152636059096721510286442935466766357421875',
#                             'symbol': 'fb',
#                             'total': '461586.2886343786309453207650',
#                             'transaction_code': 'sell'},
#                         {   'amount': 9502,
#                             'date': datetime.datetime(2012, 9, 18, 0, 0),
#                             'price': '3.159736135748221652619349697488360106945037841796875',
#                             'symbol': 'znga',
#                             'total': '30023.81276187960214318906083',
#                             'transaction_code': 'sell'},
#                         {   'amount': 3014,
#                             'date': datetime.datetime(2016, 9, 30, 0, 0),
#                             'price': '71.253716476955702319173724390566349029541015625',
#                             'symbol': 'crm',
#                             'total': '214758.7014615444867899896053',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6163,
#                             'date': datetime.datetime(2016, 4, 11, 0, 0),
#                             'price': '35.98775659034428286986440070904791355133056640625',
#                             'symbol': 'nvda',
#                             'total': '221792.5438662918153269743016',
#                             'transaction_code': 'sell'},
#                         {   'amount': 8328,
#                             'date': datetime.datetime(2006, 1, 24, 0, 0),
#                             'price': '38.32890003173469750663571176119148731231689453125',
#                             'symbol': 'adbe',
#                             'total': '319203.0794642865608352622075',
#                             'transaction_code': 'sell'},
#                         {   'amount': 5699,
#                             'date': datetime.datetime(2014, 5, 23, 0, 0),
#                             'price': '61.3428810683638090495151118375360965728759765625',
#                             'symbol': 'fb',
#                             'total': '349593.0792086053477731866224',
#                             'transaction_code': 'sell'},
#                         {   'amount': 5650,
#                             'date': datetime.datetime(2013, 2, 28, 0, 0),
#                             'price': '41.7847656498884845177599345333874225616455078125',
#                             'symbol': 'crm',
#                             'total': '236083.9259218699375253436301',
#                             'transaction_code': 'buy'},
#                         {   'amount': 234,
#                             'date': datetime.datetime(2014, 6, 6, 0, 0),
#                             'price': '51.785954760057165913167409598827362060546875',
#                             'symbol': 'crm',
#                             'total': '12117.91341385337682368117385',
#                             'transaction_code': 'buy'},
#                         {   'amount': 2505,
#                             'date': datetime.datetime(2007, 11, 21, 0, 0),
#                             'price': '42.167899569512684365690802223980426788330078125',
#                             'symbol': 'adbe',
#                             'total': '105630.5884216292743360554596',
#                             'transaction_code': 'buy'},
#                         {   'amount': 3338,
#                             'date': datetime.datetime(2015, 7, 20, 0, 0),
#                             'price': '660.2625767251601018870132975280284881591796875',
#                             'symbol': 'goog',
#                             'total': '2203956.481108584420098850387',
#                             'transaction_code': 'sell'},
#                         {   'amount': 3284,
#                             'date': datetime.datetime(2012, 9, 26, 0, 0),
#                             'price': '2.80596047854751073913348591304384171962738037109375',
#                             'symbol': 'znga',
#                             'total': '9214.774211550025267314367738',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6504,
#                             'date': datetime.datetime(2015, 4, 23, 0, 0),
#                             'price': '387.70288129646502284231246449053287506103515625',
#                             'symbol': 'amzn',
#                             'total': '2521619.539952208508566400269',
#                             'transaction_code': 'sell'},
#                         {   'amount': 4346,
#                             'date': datetime.datetime(2015, 4, 14, 0, 0),
#                             'price': '534.383224822365946238278411328792572021484375',
#                             'symbol': 'goog',
#                             'total': '2322429.495078002402351557976',
#                             'transaction_code': 'sell'},
#                         {   'amount': 1,
#                             'date': datetime.datetime(2014, 4, 23, 0, 0),
#                             'price': '325.0592684185986627198872156441211700439453125',
#                             'symbol': 'amzn',
#                             'total': '325.0592684185986627198872156',
#                             'transaction_code': 'sell'},
#                         {   'amount': 1258,
#                             'date': datetime.datetime(2016, 4, 14, 0, 0),
#                             'price': '752.8422295605332692502997815608978271484375',
#                             'symbol': 'goog',
#                             'total': '947075.5247871508527168771252',
#                             'transaction_code': 'buy'},
#                         {   'amount': 2053,
#                             'date': datetime.datetime(2013, 3, 5, 0, 0),
#                             'price': '27.925877467966198963722490589134395122528076171875',
#                             'symbol': 'fb',
#                             'total': '57331.82644173460647252227318',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4011,
#                             'date': datetime.datetime(2015, 10, 20, 0, 0),
#                             'price': '7.34747738309304754267259340849705040454864501953125',
#                             'symbol': 'bb',
#                             'total': '29470.73178358621369365977216',
#                             'transaction_code': 'buy'}]}
# {   '_id': ObjectId('5ca4bbc1a2dd94ee58162169'),
#     'account_id': 738145,
#     'bucket_end_date': datetime.datetime(2016, 12, 31, 0, 0),
#     'bucket_start_date': datetime.datetime(2003, 9, 11, 0, 0),
#     'transaction_count': 10,
#     'transactions': [   {   'amount': 5385,
#                             'date': datetime.datetime(2008, 8, 8, 0, 0),
#                             'price': '10.6612988743337524510934599675238132476806640625',
#                             'symbol': 'ebay',
#                             'total': '57411.09443828725694913828193',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2343,
#                             'date': datetime.datetime(2016, 10, 12, 0, 0),
#                             'price': '27.88433145140361801850303891114890575408935546875',
#                             'symbol': 'team',
#                             'total': '65332.98859063867701735262017',
#                             'transaction_code': 'buy'},
#                         {   'amount': 886,
#                             'date': datetime.datetime(2006, 6, 13, 0, 0),
#                             'price': '12.8700894878201079762902736547403037548065185546875',
#                             'symbol': 'ebay',
#                             'total': '11402.89928620861566699318246',
#                             'transaction_code': 'buy'},
#                         {   'amount': 7448,
#                             'date': datetime.datetime(2016, 12, 6, 0, 0),
#                             'price': '25.4047226982834075670325546525418758392333984375',
#                             'symbol': 'team',
#                             'total': '189214.3746568148195592584671',
#                             'transaction_code': 'sell'},
#                         {   'amount': 6425,
#                             'date': datetime.datetime(2016, 6, 1, 0, 0),
#                             'price': '23.285958477611853112421158584766089916229248046875',
#                             'symbol': 'team',
#                             'total': '149612.2832186561562473059439',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2644,
#                             'date': datetime.datetime(2005, 5, 4, 0, 0),
#                             'price': '19.286994398572840481165258097462356090545654296875',
#                             'symbol': 'intc',
#                             'total': '50994.81318982659023220094241',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4843,
#                             'date': datetime.datetime(2014, 7, 23, 0, 0),
#                             'price': '31.04601976138456365106321754865348339080810546875',
#                             'symbol': 'intc',
#                             'total': '150355.8737043854417620991626',
#                             'transaction_code': 'buy'},
#                         {   'amount': 116,
#                             'date': datetime.datetime(2016, 11, 8, 0, 0),
#                             'price': '27.176855000824406971560165402479469776153564453125',
#                             'symbol': 'team',
#                             'total': '3152.515180095631208700979187',
#                             'transaction_code': 'sell'},
#                         {   'amount': 630,
#                             'date': datetime.datetime(2004, 9, 3, 0, 0),
#                             'price': '15.9872944477099654392304728389717638492584228515625',
#                             'symbol': 'intc',
#                             'total': '10071.99550205727822671519789',
#                             'transaction_code': 'buy'},
#                         {   'amount': 9440,
#                             'date': datetime.datetime(2016, 7, 14, 0, 0),
#                             'price': '27.447440981351775235452805645763874053955078125',
#                             'symbol': 'team',
#                             'total': '259103.8428639607582226744853',
#                             'transaction_code': 'buy'}]}
# {   '_id': ObjectId('5ca4bbc1a2dd94ee5816221e'),
#     'account_id': 840433,
#     'bucket_end_date': datetime.datetime(2016, 3, 21, 0, 0),
#     'bucket_start_date': datetime.datetime(2003, 12, 19, 0, 0),
#     'transaction_count': 3,
#     'transactions': [   {   'amount': 8067,
#                             'date': datetime.datetime(2006, 6, 28, 0, 0),
#                             'price': '11.971589367464464004342517000623047351837158203125',
#                             'symbol': 'ebay',
#                             'total': '96574.81142733583112303108464',
#                             'transaction_code': 'sell'},
#                         {   'amount': 9802,
#                             'date': datetime.datetime(2014, 8, 13, 0, 0),
#                             'price': '329.68258592554548158659599721431732177734375',
#                             'symbol': 'amzn',
#                             'total': '3231548.707242196810511813965',
#                             'transaction_code': 'sell'},
#                         {   'amount': 8954,
#                             'date': datetime.datetime(2014, 5, 8, 0, 0),
#                             'price': '50.93270562103149501353982486762106418609619140625',
#                             'symbol': 'crm',
#                             'total': '456051.4461307160063512355919',
#                             'transaction_code': 'sell'}]}
# {   '_id': ObjectId('5ca4bbc1a2dd94ee58162318'),
#     'account_id': 726966,
#     'bucket_end_date': datetime.datetime(2016, 3, 10, 0, 0),
#     'bucket_start_date': datetime.datetime(2003, 5, 30, 0, 0),
#     'transaction_count': 4,
#     'transactions': [   {   'amount': 4716,
#                             'date': datetime.datetime(2009, 4, 22, 0, 0),
#                             'price': '12.1696480928421966183350377832539379596710205078125',
#                             'symbol': 'intc',
#                             'total': '57392.06040584379925206803819',
#                             'transaction_code': 'buy'},
#                         {   'amount': 9677,
#                             'date': datetime.datetime(2015, 12, 8, 0, 0),
#                             'price': '673.7752742770427403229405172169208526611328125',
#                             'symbol': 'amzn',
#                             'total': '6520123.329178942598105095385',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6997,
#                             'date': datetime.datetime(2003, 8, 29, 0, 0),
#                             'price': '45.7312982518946142818094813264906406402587890625',
#                             'symbol': 'amzn',
#                             'total': '319981.8938685066161298209408',
#                             'transaction_code': 'buy'},
#                         {   'amount': 2244,
#                             'date': datetime.datetime(2008, 8, 28, 0, 0),
#                             'price': '81.9173893144353684192537912167608737945556640625',
#                             'symbol': 'amzn',
#                             'total': '183822.6216215929667328055075',
#                             'transaction_code': 'sell'}]}

# %%
# AND - Busca la misma cuenta y filtra además por la fecha de transacción
# Nested query

filter = {
    "$and": [{"account_id": 716662}, {"transactions":{"$elemMatch":{'symbol':'amd', 'transaction_code':'buy'}}}]        # Este query busca transacciones que sean de la cuenta 716662 o que sean de cualquier cuenta pero sean compra de AMD
}

result = client['sample_analytics']['transactions'].find(filter=filter)

for doc in result:
    pp.pprint(doc)
# Out:
# {   '_id': ObjectId('5ca4bbc1a2dd94ee58161cb2'),
#     'account_id': 716662,
#     'bucket_end_date': datetime.datetime(2016, 12, 27, 0, 0),
#     'bucket_start_date': datetime.datetime(1962, 5, 13, 0, 0),
#     'transaction_count': 48,
#     'transactions': [   {   'amount': 8592,
#                             'date': datetime.datetime(2008, 3, 19, 0, 0),
#                             'price': '6.25868566899633460565155473886989057064056396484375',
#                             'symbol': 'amd',
#                             'total': '53774.62726801650693175815832',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5360,
#                             'date': datetime.datetime(2008, 5, 27, 0, 0),
#                             'price': '6.8846943545406844577883020974695682525634765625',
#                             'symbol': 'amd',
#                             'total': '36901.96174033806869374529924',
#                             'transaction_code': 'sell'},
#                         {   'amount': 4878,
#                             'date': datetime.datetime(2015, 11, 5, 0, 0),
#                             'price': '2.226658409790678749828884974704124033451080322265625',
#                             'symbol': 'amd',
#                             'total': '10861.63972295893094166530091',
#                             'transaction_code': 'buy'},
#                         {   'amount': 653,
#                             'date': datetime.datetime(2015, 10, 21, 0, 0),
#                             'price': '2.373837436769802078373459153226576745510101318359375',
#                             'symbol': 'znga',
#                             'total': '1550.115846210680757177868827',
#                             'transaction_code': 'sell'},
#                         {   'amount': 8043,
#                             'date': datetime.datetime(2014, 12, 9, 0, 0),
#                             'price': '2.4728822736764062284464671392925083637237548828125',
#                             'symbol': 'znga',
#                             'total': '19889.39212717933529539493520',
#                             'transaction_code': 'sell'},
#                         {   'amount': 5675,
#                             'date': datetime.datetime(2006, 4, 27, 0, 0),
#                             'price': '32.416346686685045597187126986682415008544921875',
#                             'symbol': 'amd',
#                             'total': '183962.7674469376337640369456',
#                             'transaction_code': 'buy'},
#                         {   'amount': 7127,
#                             'date': datetime.datetime(1973, 2, 6, 0, 0),
#                             'price': '17.956209262859136543966087629087269306182861328125',
#                             'symbol': 'ibm',
#                             'total': '127973.9034163970661488463065',
#                             'transaction_code': 'sell'},
#                         {   'amount': 9428,
#                             'date': datetime.datetime(2013, 10, 4, 0, 0),
#                             'price': '160.086898842170427315068081952631473541259765625',
#                             'symbol': 'ibm',
#                             'total': '1509299.282283982788726461877',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4762,
#                             'date': datetime.datetime(1994, 8, 2, 0, 0),
#                             'price': '13.3279381594159982427072463906370103359222412109375',
#                             'symbol': 'amd',
#                             'total': '63467.64151513898363177190731',
#                             'transaction_code': 'buy'},
#                         {   'amount': 3750,
#                             'date': datetime.datetime(2013, 2, 12, 0, 0),
#                             'price': '3.3629426011610643598714887048117816448211669921875',
#                             'symbol': 'znga',
#                             'total': '12611.03475435399134951808264',
#                             'transaction_code': 'sell'},
#                         {   'amount': 7508,
#                             'date': datetime.datetime(1990, 3, 29, 0, 0),
#                             'price': '22.209380146876792849752746406011283397674560546875',
#                             'symbol': 'ibm',
#                             'total': '166748.0261427509607159436200',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2157,
#                             'date': datetime.datetime(2015, 2, 20, 0, 0),
#                             'price': '2.310551619513003362982317412388511002063751220703125',
#                             'symbol': 'znga',
#                             'total': '4983.859843289548253952858659',
#                             'transaction_code': 'sell'},
#                         {   'amount': 6178,
#                             'date': datetime.datetime(2009, 5, 20, 0, 0),
#                             'price': '87.2363145379931808065521181561052799224853515625',
#                             'symbol': 'ibm',
#                             'total': '538945.9512157218710228789860',
#                             'transaction_code': 'buy'},
#                         {   'amount': 2348,
#                             'date': datetime.datetime(1987, 9, 8, 0, 0),
#                             'price': '33.09028484414860571405370137654244899749755859375',
#                             'symbol': 'ibm',
#                             'total': '77695.98881406092621659809083',
#                             'transaction_code': 'sell'},
#                         {   'amount': 1636,
#                             'date': datetime.datetime(1968, 5, 22, 0, 0),
#                             'price': '13.7785547229763576382310930057428777217864990234375',
#                             'symbol': 'ibm',
#                             'total': '22541.71552678932109614606816',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4041,
#                             'date': datetime.datetime(2016, 5, 6, 0, 0),
#                             'price': '3.7014628783847296489284417475573718547821044921875',
#                             'symbol': 'amd',
#                             'total': '14957.61149155269251131983310',
#                             'transaction_code': 'buy'},
#                         {   'amount': 8320,
#                             'date': datetime.datetime(2016, 3, 1, 0, 0),
#                             'price': '2.135230517281893281023030795040540397167205810546875',
#                             'symbol': 'amd',
#                             'total': '17765.11790378535209811161621',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5839,
#                             'date': datetime.datetime(1998, 9, 2, 0, 0),
#                             'price': '51.42269939080775742468176758848130702972412109375',
#                             'symbol': 'ibm',
#                             'total': '300257.1417429264956027168409',
#                             'transaction_code': 'sell'},
#                         {   'amount': 7424,
#                             'date': datetime.datetime(2010, 5, 21, 0, 0),
#                             'price': '7.85096989677664236495502336765639483928680419921875',
#                             'symbol': 'amd',
#                             'total': '58285.60051366979291742609348',
#                             'transaction_code': 'buy'},
#                         {   'amount': 1570,
#                             'date': datetime.datetime(1992, 11, 18, 0, 0),
#                             'price': '8.1172357797963687886522166081704199314117431640625',
#                             'symbol': 'amd',
#                             'total': '12744.06017428029899818398007',
#                             'transaction_code': 'sell'},
#                         {   'amount': 4035,
#                             'date': datetime.datetime(2006, 3, 28, 0, 0),
#                             'price': '35.0030390814623473261235631071031093597412109375',
#                             'symbol': 'amd',
#                             'total': '141237.2626937005714609085771',
#                             'transaction_code': 'buy'},
#                         {   'amount': 2396,
#                             'date': datetime.datetime(1983, 8, 3, 0, 0),
#                             'price': '14.59782750387503114097853540442883968353271484375',
#                             'symbol': 'amd',
#                             'total': '34976.39469928457461378457083',
#                             'transaction_code': 'sell'},
#                         {   'amount': 7561,
#                             'date': datetime.datetime(1992, 11, 4, 0, 0),
#                             'price': '14.357152597134703597703264676965773105621337890625',
#                             'symbol': 'ibm',
#                             'total': '108554.4307869354939022343842',
#                             'transaction_code': 'sell'},
#                         {   'amount': 8861,
#                             'date': datetime.datetime(2016, 7, 15, 0, 0),
#                             'price': '2.770691871315896559480052019353024661540985107421875',
#                             'symbol': 'znga',
#                             'total': '24551.10067173015941355274094',
#                             'transaction_code': 'sell'},
#                         {   'amount': 989,
#                             'date': datetime.datetime(2016, 8, 5, 0, 0),
#                             'price': '2.80697525503529021762005868367850780487060546875',
#                             'symbol': 'znga',
#                             'total': '2776.098527229902025226238038',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6991,
#                             'date': datetime.datetime(1991, 12, 27, 0, 0),
#                             'price': '18.54093120162320929011912085115909576416015625',
#                             'symbol': 'ibm',
#                             'total': '129619.6500305478561472227739',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4448,
#                             'date': datetime.datetime(1990, 8, 13, 0, 0),
#                             'price': '2.838456255649362436344063098658807575702667236328125',
#                             'symbol': 'amd',
#                             'total': '12625.45342512836411685839266',
#                             'transaction_code': 'buy'},
#                         {   'amount': 1390,
#                             'date': datetime.datetime(1969, 5, 12, 0, 0),
#                             'price': '13.518939299984577218083359184674918651580810546875',
#                             'symbol': 'ibm',
#                             'total': '18791.32562697856233313586927',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5871,
#                             'date': datetime.datetime(2015, 7, 21, 0, 0),
#                             'price': '1.7818592313361925061343526976997964084148406982421875',
#                             'symbol': 'amd',
#                             'total': '10461.29554717478620351478469',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5780,
#                             'date': datetime.datetime(2013, 3, 13, 0, 0),
#                             'price': '2.57150053033337311347850118181668221950531005859375',
#                             'symbol': 'amd',
#                             'total': '14863.27306532689659590573683',
#                             'transaction_code': 'buy'},
#                         {   'amount': 9500,
#                             'date': datetime.datetime(2015, 9, 15, 0, 0),
#                             'price': '135.51450066929822924066684208810329437255859375',
#                             'symbol': 'ibm',
#                             'total': '1287387.756358333177786335000',
#                             'transaction_code': 'sell'},
#                         {   'amount': 242,
#                             'date': datetime.datetime(2014, 3, 5, 0, 0),
#                             'price': '164.977497536350909967950428836047649383544921875',
#                             'symbol': 'ibm',
#                             'total': '39924.55440379692021224400378',
#                             'transaction_code': 'sell'},
#                         {   'amount': 1810,
#                             'date': datetime.datetime(2006, 10, 12, 0, 0),
#                             'price': '24.215488489677564842850188142620027065277099609375',
#                             'symbol': 'amd',
#                             'total': '43830.03416631639236555884054',
#                             'transaction_code': 'sell'},
#                         {   'amount': 3630,
#                             'date': datetime.datetime(2016, 1, 21, 0, 0),
#                             'price': '2.309741010601587873907192260958254337310791015625',
#                             'symbol': 'znga',
#                             'total': '8384.359868483763982283107907',
#                             'transaction_code': 'buy'},
#                         {   'amount': 6707,
#                             'date': datetime.datetime(2008, 1, 24, 0, 0),
#                             'price': '7.6788139003430675444406006135977804660797119140625',
#                             'symbol': 'amd',
#                             'total': '51501.80482960095402056310832',
#                             'transaction_code': 'sell'},
#                         {   'amount': 9063,
#                             'date': datetime.datetime(2010, 5, 10, 0, 0),
#                             'price': '8.8885831792233371828615418053232133388519287109375',
#                             'symbol': 'amd',
#                             'total': '80557.22935330110488827415338',
#                             'transaction_code': 'buy'},
#                         {   'amount': 4984,
#                             'date': datetime.datetime(2001, 4, 30, 0, 0),
#                             'price': '98.400576663388932274756371043622493743896484375',
#                             'symbol': 'ibm',
#                             'total': '490428.4740903304384573857533',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2859,
#                             'date': datetime.datetime(2004, 11, 3, 0, 0),
#                             'price': '17.91427224913838500697238487191498279571533203125',
#                             'symbol': 'amd',
#                             'total': '51216.90436028664273493404835',
#                             'transaction_code': 'buy'},
#                         {   'amount': 3420,
#                             'date': datetime.datetime(2016, 4, 13, 0, 0),
#                             'price': '140.642065711619352441630326211452484130859375',
#                             'symbol': 'ibm',
#                             'total': '480995.8647337381853503757156',
#                             'transaction_code': 'sell'},
#                         {   'amount': 346,
#                             'date': datetime.datetime(1995, 7, 26, 0, 0),
#                             'price': '22.558316628407485637808349565602838993072509765625',
#                             'symbol': 'ibm',
#                             'total': '7805.177553428990030681688950',
#                             'transaction_code': 'sell'},
#                         {   'amount': 5663,
#                             'date': datetime.datetime(2016, 2, 2, 0, 0),
#                             'price': '2.40749676118021138648828127770684659481048583984375',
#                             'symbol': 'znga',
#                             'total': '13633.65415856353708168313688',
#                             'transaction_code': 'sell'},
#                         {   'amount': 3840,
#                             'date': datetime.datetime(2006, 4, 18, 0, 0),
#                             'price': '69.471924401937911852655815891921520233154296875',
#                             'symbol': 'ibm',
#                             'total': '266772.1897034415815141983330',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5448,
#                             'date': datetime.datetime(2005, 8, 26, 0, 0),
#                             'price': '21.048637651672013504366987035609781742095947265625',
#                             'symbol': 'amd',
#                             'total': '114672.9779263091295717913454',
#                             'transaction_code': 'buy'},
#                         {   'amount': 5852,
#                             'date': datetime.datetime(1987, 9, 24, 0, 0),
#                             'price': '32.2390980086532152881773072294890880584716796875',
#                             'symbol': 'ibm',
#                             'total': '188663.2015466386158664136019',
#                             'transaction_code': 'sell'},
#                         {   'amount': 9019,
#                             'date': datetime.datetime(2014, 12, 26, 0, 0),
#                             'price': '2.74631542297262232210641741403378546237945556640625',
#                             'symbol': 'znga',
#                             'total': '24769.01879979008072307777866',
#                             'transaction_code': 'sell'},
#                         {   'amount': 8260,
#                             'date': datetime.datetime(2003, 12, 31, 0, 0),
#                             'price': '15.072997391334343575408638571389019489288330078125',
#                             'symbol': 'amd',
#                             'total': '124502.9584524216779328753546',
#                             'transaction_code': 'sell'},
#                         {   'amount': 2753,
#                             'date': datetime.datetime(2015, 5, 21, 0, 0),
#                             'price': '2.958834542401841627423664249363355338573455810546875',
#                             'symbol': 'znga',
#                             'total': '8145.671495232270000297347678',
#                             'transaction_code': 'sell'},
#                         {   'amount': 3875,
#                             'date': datetime.datetime(2012, 1, 31, 0, 0),
#                             'price': '6.7735134650038713033382009598426520824432373046875',
#                             'symbol': 'amd',
#                             'total': '26247.36467689000130043552872',
#                             'transaction_code': 'sell'}]}

# %%
# Añadir información
db = client['sample_analytics']
mycollection = db['transactions']

result = mycollection.insert_one(
    {
        'account_id' : "010101"
    }
)

# Se puede ver en la interfaz

# %%
# Se puede añadir un documento más complejo a la base de datos 
result = mycollection.insert_one(
    {
        "account_id": '0101044',
        'bucket_start_date': start,
        'bucket_end_date': end,
        'transaction_count': 1,
        'transactions': [
            {
                'amount': 1000,
                'symbol': 'ibm',
                'transaction_code': 'buy',
                'date': start
            },
            {
                'amount': 2000,
                'symbol': 'ibm',
                'transaction_code': 'sell',
                'date': end
            }
        ]
    }
)

# %% [markdown]
# ### Actualización de datos

# %%
# Actualización update_one() y update_many()
start = datetime(2022,11,5,1,1,1)

mycollection.update_one(
    {'account_id': '010101'},
    {'$set': {'bucket_start_date': start}}
)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000052'), 'opTime': {'ts': Timestamp(1699331691, 8), 't': 82}, 'nModified': 0, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1699331691, 8), 'signature': {'hash': b'\x056}\xf4\xa1\xe7\xdd\xfas\x8c\xf1\xe4k\xbf-\xbd\xce\xc08\xb7', 'keyId': 7256046250988929031}}, 'operationTime': Timestamp(1699331691, 8), 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# ### Eliminar datos

# %%
mycollection.delete_one(
    {'account_id': '010101'}
)
# Out:
# DeleteResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000052'), 'opTime': {'ts': Timestamp(1699331750, 2), 't': 82}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1699331750, 2), 'signature': {'hash': b'z\x84;\xd3\x0c\x03\x1d}\x89O\xa0\xc0a\xcc\x03wd\xea\xcb\xb3', 'keyId': 7256046250988929031}}, 'operationTime': Timestamp(1699331750, 2)}, acknowledged=True)
